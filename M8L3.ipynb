# %% [markdown]
# <a href="https://colab.research.google.com/github/MancheelaNithinkumar/FMML_Project_and_Labs/blob/main/M8L3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# Lab by V Vijay Vignesh
#
# vijay.vignesh@research.iiit.ac.in

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2025-04-08 04:34:28--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   138MB/s    in 0.5s
#
# 2025-04-08 04:34:30 (138 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False),
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split()
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 13306   0804.4809v1  Many neural learning algorithms require to sol...    cs
# 6210   1609.05772v1  This paper considers a restriction to non-nega...  stat
# 28142  1705.07632v3  Computer vision has been introduced to estimat...    cs
# 6233   1610.01417v1  Privacy preserving networks can be modelled as...  stat
# 36156   1207.1428v1  Maximal ancestral graphs (MAGs) are used to en...  stat
# ...             ...                                                ...   ...
# 7218   1711.02478v2  This paper introduces the combinatorial Boolea...  stat
# 32056   1406.6114v1  In this research we address the problem of cap...    cs
# 20822  1703.04361v1  "Cognitive synergy" refers to a dynamic in whi...    cs
# 2557   1605.00596v1  We investigate an efficient context-dependent ...  stat
# 37935   1204.0991v2  Deregulation of energy markets, penetration of...  stat
#
#                                                    title  year  \
# 13306  Fast Computation of Moore-Penrose Inverse Matr...  2008
# 6210                     Stochastic Matrix Factorization  2016
# 28142  Computer vision-based food calorie estimation:...  2017
# 6233   Decentralized Topic Modelling with Latent Diri...  2016
# 36156  Generating Markov Equivalent Maximal Ancestral...  2012
# ...                                                  ...   ...
# 7218   Grafting for Combinatorial Boolean Model using...  2017
# 32056  Mining Recurrent Concepts in Data Streams usin...  2014
# 20822         Toward a Formal Model of Cognitive Synergy  2017
# 2557         Graph Clustering Bandits for Recommendation  2016
# 37935   Distributed Robust Power System State Estimation  2012
#
#                                                 keywords
# 13306  [algorithms, deficiency, contribute, regulariz...
# 6210   [considers, restriction, factorization, stocha...
# 28142  [introduced, incomplete, estimation, detection...
# 6233   [preserving, decentralized, connected, communi...
# 36156  [ancestral, conditional, independence, relatio...
# ...                                                  ...
# 7218   [introduces, combinatorial, combinations, conj...
# 32056  [capturing, recurring, environment, recurrence...
# 20822  [cognitive, cognitive, processes, cooperating,...
# 2557   [investigate, efficient, dependent, clustering...
# 37935  [deregulation, penetration, renewables, capabi...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 13306    [algorithms, deficiency, contribute, regulariz...
# 6210     [considers, restriction, factorization, stocha...
# 28142    [introduced, incomplete, estimation, detection...
# 6233     [preserving, decentralized, connected, communi...
# 36156    [ancestral, conditional, independence, relatio...
#                                ...
# 34425    [authorship, attribution, processing, statisti...
# 1080     [applications, outperforming, important, theor...
# 10343    [unsupervised, estimation, fundamental, applic...
# 7870     [publications, investigated, modelling, optimi...
# 1779     [successfully, applications, discriminative, e...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]),
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8851 words.
# Out of those 4577 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="9913c7ef-7566-49a1-84f2-e25449260a0f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9913c7ef-7566-49a1-84f2-e25449260a0f")) {                    Plotly.newPlot(                        "9913c7ef-7566-49a1-84f2-e25449260a0f",                        [{"x":["substantially","regularization","computing","factorization","resulting","particularly","deficiency","algorithm","computation","pseudoinverse","algorithms","contribute","unstructured","characterizes","restriction","estimator","sufficient","economics","consistent","analyzing","retrieving","stochastic","parameters","illustrated","considers","conditions","necessary","abstracts","introduced","calibration","experiment","corresponding","information","estimation","incomplete","detection","effective","annotation","reference","accessing","synthetic","optimizing","connected","optimization","confidential","decentralized","allocation","communication","performance","dirichlet","modelling","preserving","controlled","equivalent","undirected","conditional","independences","replacement","independence","relations","generating","ancestral","variables","different","represent","techniques","augmentation","riemannian","demonstrated","inference","difficulties","gradients","alternative","representation","marginalization","exploiting","constrained","challenging","approximation","probabilistic","representing","structure","independencies","probability","uncertainty","distribution","frequency","reporting","determining","graphical","probabilities","variances","application","distortion","quantization","specifically","correction","introduce","complexity","robustness","classification","classifiers","replication","strategies","traditional","polynomial","correcting","minimizing","corrupted","redundancy","multiplication","classifier","optimized","resolution","understanding","properties","validation","arbitrarily","significant","guarantee","challenge","distributions","predictive","previously","fundamental","illustrate","tradeoffs","observing","instances","formulated","supervise","appropriate","parametrizes","relaxation","computational","assignment","collection","quadratic","interested","structural","substitute","impossible","efficient","expensive","eventually","reliability","simulation","prescribed","substitution","functions","substituting","augmented","importance","surrogate","metamodel","expansions","engineering","analytical","reconstructed","unobserved","independently","navigation","approaches","environments","reconstruction","magnitude","framework","acquisition","technique","binocular","separation","conventional","mathematical","situations","sensitivity","monocular","environment","processing","scenarios","direction","applications","constructing","experiments","recognition","challenges","extensive","contribution","convolutional","intellectual","exploring","facilitate","comprehensive","protection","axiomatic","relationships","presented","perspective","evaluating","presenting","partition"],"y":[43,64,129,42,154,77,4,828,151,2,577,30,13,8,10,23,74,1,87,59,14,138,246,21,34,144,80,6,126,18,78,136,684,242,38,342,268,74,54,5,130,43,62,313,2,5,30,65,877,31,53,45,31,56,8,79,0,8,27,89,94,0,126,730,126,375,29,8,97,219,25,33,104,356,7,71,59,270,124,168,60,324,2,172,93,198,55,13,44,55,57,10,240,18,21,157,29,346,228,86,504,119,1,92,186,59,18,59,21,19,9,149,61,112,175,227,58,20,259,35,144,111,63,101,92,73,3,26,93,32,2,84,1,27,306,31,84,27,21,77,3,14,373,63,15,28,79,6,6,224,3,32,69,12,1,3,46,23,25,7,44,34,474,75,89,67,523,38,264,2,24,97,74,46,45,27,123,290,90,53,425,38,617,392,118,166,64,379,2,39,31,57,8,9,72,186,79,50,20,22],"type":"bar"},{"x":["substantially","regularization","computing","factorization","resulting ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4577,), (4577, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.8183333333333334

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Why</span> <span style=''>we</span> <span style=''>have</span> <span style=''>switched</span> <span style=''>from</span> <span style=''>building</span> <span style=''>full</span> <span style=''>fledged</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>taxonomies</span> <span style=''>to</span> <span style=''>simply</span> <span style='background-color:rgba(0, 255, 0, 0.3277310924369748);'>detecting</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>hypernymy</span> <span style='background-color:rgba(0, 255, 0, 0.49579831932773105);'>relations</span> <br/><br/><span style=''>The</span> <span style=''>study</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>taxonomies</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>hypernymy</span> <span style='background-color:rgba(0, 255, 0, 0.49579831932773105);'>relations</span> <span style=''>has</span> <span style=''>been</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>extensive</span> <span style=''>on</span> <span style=''>the</span> <span style=''>Natural</span> <span style=''>Language</span> <span style='background-color:rgba(0, 255, 0, 0.4285714285714286);'>Processing</span> <span style=''>(NLP)</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>literature</span> <span style=''>However</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.42364532019704443);'>evaluation</span> <span style=''>of</span> <span style=''>taxonomy</span> <span style=''>learning</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>approaches</span> <span style=''>has</span> <span style=''>been</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>traditionally</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>troublesome</span> <span style=''>as</span> <span style=''>it</span> <span style=''>mainly</span> <span style=''>relies</span> <span style=''>on</span> <span style=''>ad</span> <span style=''>hoc</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>experiments</span> <span style=''>which</span> <span style=''>are</span> <span style=''>hardly</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>reproducible</span> <span style=''>and</span> <span style=''>manually</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>expensive</span> <span style=''>Partly</span> <span style=''>because</span> <span style=''>of</span> <span style=''>this</span> <span style=''>current</span> <span style=''>research</span> <span style=''>has</span> <span style=''>been</span> <span style=''>lately</span> <span style=''>focusing</span> <span style=''>on</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>hypernymy</span> <span style='background-color:rgba(0, 255, 0, 0.5580865603644648);'>detection</span> <span style=''>task</span> <span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>reflect</span> <span style=''>on</span> <span style=''>this</span> <span style=''>trend</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>analyzing</span> <span style=''>issues</span> <span style=''>related</span> <span style=''>to</span> <span style=''>current</span> <span style='background-color:rgba(0, 255, 0, 0.42364532019704443);'>evaluation</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>procedures</span> <span style=''>Finally</span> <span style=''>we</span> <span style=''>propose</span> <span style=''>three</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>potential</span> <span style=''>avenues</span> <span style=''>for</span> <span style=''>future</span> <span style=''>work</span> <span style=''>so</span> <span style=''>that</span> <span style=''>is</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.49579831932773105);'>relations</span> <span style=''>and</span> <span style='background-co ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Learning</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Densities</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Conditional</span> <span style=''>on</span> <span style=''>Many</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Interacting</span> <span style=''>Features</span> <br/><br/><span style=''>Learning</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>distribution</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>conditional</span> <span style=''>on</span> <span style=''>a</span> <span style=''>set</span> <span style=''>of</span> <span style=''>discrete</span> <span style=''>valued</span> <span style=''>features</span> <span style=''>is</span> <span style=''>a</span> <span style=''>commonly</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>encountered</span> <span style=''>task</span> <span style=''>This</span> <span style=''>becomes</span> <span style=''>more</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>challenging</span> <span style=''>with</span> <span style=''>a</span> <span style=''>high</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dimensional</span> <span style=''>feature</span> <span style=''>set</span> <span style=''>when</span> <span style=''>there</span> <span style=''>is</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>possibility</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>interaction</span> <span style=''>between</span> <span style=''>the</span> <span style=''>features</span> <span style=''>In</span> <span style=''>addition</span> <span style=''>many</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>frequently</span> <span style=''>applied</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>techniques</span> <span style=''>consider</span> <span style=''>only</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>prediction</span> <span style=''>of</span> <span style=''>the</span> <span style=''>mean</span> <span style=''>but</span> <span style=''>the</span> <span style=''>complete</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>conditional</span> <span style=''>density</span> <span style=''>is</span> <span style=''>needed</span> <span style=''>to</span> <span style=''>answer</span> <span style=''>more</span> <span style=''>complex</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>questions</span> <span style=''>We</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>demonstrate</span> <span style=''>a</span> <span style=''>novel</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>nonparametric</span> <span style=''>Bayes</span> <span style=''>method</span> <span style=''>based</span> <span style=''>upon</span> <span style=''>a</span> <span style=''>tensor</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>factorization</span> <span style=''>of</span> <span style=''>feature</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>dependent</span> <span style=''>weights</span> <span style=''>for</span> <span style=''>Gaussian</span> <span style=''>kernels</span> <span style=''>The</span> <span style=''>method</span> <span style=''>makes</span> <span style=''>use</span> <span style=''>of</span> <span style=''>multistage</span> <span style=''>feature</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>selection</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dimension</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>reduction</span> <span style=''>The</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>resulting</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>conditional</span> <span style=''>density</span> <span style=''>morphs</span> <span style=''>flexibly</span> <span style=''>with</span> <span style=''>the</span> <span style=''>selected</span> <span s ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(0, 255, 0, 0.3);'>Identifying</span> <span style=''>the</span> <span style=''>Relevant</span> <span style=''>Nodes</span> <span style=''>Without</span> <span style=''>Learning</span> <span style=''>the</span> <span style=''>Model</span> <br/><br/><span style=''>We</span> <span style=''>propose</span> <span style=''>a</span> <span style=''>method</span> <span style=''>to</span> <span style=''>identify</span> <span style=''>all</span> <span style=''>the</span> <span style=''>nodes</span> <span style=''>that</span> <span style=''>are</span> <span style=''>relevant</span> <span style=''>to</span> <span style=''>compute</span> <span style=''>all</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>conditional</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>probability</span> <span style='background-color:rgba(255, 0, 0, 0.3675213675213676);'>distributions</span> <span style=''>for</span> <span style=''>a</span> <span style=''>given</span> <span style=''>set</span> <span style=''>of</span> <span style=''>nodes</span> <span style=''>Our</span> <span style=''>method</span> <span style=''>is</span> <span style=''>simple</span> <span style=''>effcient</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>consistent</span> <span style=''>and</span> <span style=''>does</span> <span style=''>not</span> <span style=''>require</span> <span style=''>learning</span> <span style=''>a</span> <span style=''>Bayesian</span> <span style=''>network</span> <span style=''>first</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Therefore</span> <span style=''>our</span> <span style=''>method</span> <span style=''>can</span> <span style=''>be</span> <span style=''>applied</span> <span style=''>to</span> <span style=''>high</span> <span style='background-color:rgba(255, 0, 0, 0.35008976660682234);'>dimensional</span> <span style='background-color:rgba(0, 255, 0, 0.5428571428571427);'>databases</span> <span style=''>eg</span> <span style=''>gene</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>expression</span> <span style='background-color:rgba(0, 255, 0, 0.5428571428571427);'>databases</span> <br/><br/>

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Online</span> <span style=''>Learning</span> <span style=''>with</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Predictable</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Sequences</span> <br/><br/><span style=''>We</span> <span style=''>present</span> <span style=''>methods</span> <span style=''>for</span> <span style=''>online</span> <span style=''>linear</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>optimization</span> <span style=''>that</span> <span style=''>take</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>advantage</span> <span style=''>of</span> <span style=''>benign</span> <span style=''>(as</span> <span style=''>opposed</span> <span style=''>to</span> <span style=''>worst</span> <span style=''>case)</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>sequences</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Specifically</span> <span style=''>if</span> <span style=''>the</span> <span style=''>sequence</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>encountered</span> <span style=''>by</span> <span style=''>the</span> <span style=''>learner</span> <span style=''>is</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>described</span> <span style=''>well</span> <span style=''>by</span> <span style=''>a</span> <span style=''>known</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>predictable</span> <span style=''>process</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithms</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>presented</span> <span style=''>enjoy</span> <span style=''>tighter</span> <span style=''>bounds</span> <span style=''>as</span> <span style=''>compared</span> <span style=''>to</span> <span style=''>the</span> <span style=''>typical</span> <span style=''>worst</span> <span style=''>case</span> <span style=''>bounds</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Additionally</span> <span style=''>the</span> <span style=''>methods</span> <span style=''>achieve</span> <span style=''>the</span> <span style=''>usual</span> <span style=''>worst</span> <span style=''>case</span> <span style=''>regret</span> <span style=''>bounds</span> <span style=''>if</span> <span style=''>the</span> <span style=''>sequence</span> <span style=''>is</span> <span style=''>not</span> <span style=''>benign</span> <span style=''>Our</span> <span style=''>approach</span> <span style=''>can</span> <span style=''>be</span> <span style=''>seen</span> <span style=''>as</span> <span style=''>a</span> <span style=''>way</span> <span style=''>of</span> <span style=''>adding</span> <span style=''>prior</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>knowledge</span> <span style=''>about</span> <span style=''>the</span> <span style=''>sequence</span> <span style=''>within</span> <span style=''>the</span> <span style=''>paradigm</span> <span style=''>of</span> <span style=''>online</span> <span style=''>learning</span> <span style=''>The</span> <span style=''>setting</span> <span style=''>is</span> <span style=''>shown</span> <span style=''>to</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>encompass</span> <span style=''>partial</span> <span style=''>and</span> <span style=''>side</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>information</span> <span style=''>Variance</span> <span style=''>and</span> <span style=''>path</span> <span style=''>length</span> <span style=''>bounds</span> <span style=''>can</span> <span style=''>be</span> <span style=''>seen</span> <span style=''>as</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>particular</span> <span style=''>examples</span> <span style=''>of</span> <span style=''>online</span> <span style=''>learning</span> <span style=''>with</span> <span style=''>simple</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>predictable</span> <span style='background-c ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	experimental (0.1354954954954955)
# 	evaluation (0.10414414414414415)
# 	processing (0.1045045045045045)
# 	challenging (0.0972972972972973)
# 	segmentation (0.07603603603603604)
# 	information (0.2464864864864865)
# 	detection (0.12324324324324325)
# 	different (0.26306306306306304)
# 	convolutional (0.13657657657657657)
# 	recognition (0.14126126126126126)
#
# Some Statistics words are:
# 	estimation (0.16790123456790124)
# 	variables (0.13037037037037036)
# 	algorithm (0.3871604938271605)
# 	stochastic (0.14074074074074075)
# 	theoretical (0.15259259259259259)
# 	statistical (0.15703703703703703)
# 	distribution (0.1837037037037037)
# 	inference (0.19753086419753085)
# 	dimensional (0.18567901234567902)
# 	regression (0.17333333333333334)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]),
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="35c24c6c-9a15-49a3-a9e2-3b6c5e5c3059" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("35c24c6c-9a15-49a3-a9e2-3b6c5e5c3059")) {                    Plotly.newPlot(                        "35c24c6c-9a15-49a3-a9e2-3b6c5e5c3059",                        [{"x":["substantially","regularization","computing","factorization","resulting","particularly","deficiency","algorithm","computation","pseudoinverse","algorithms","contribute","unstructured","characterizes","restriction","estimator","sufficient","economics","consistent","analyzing","retrieving","stochastic","parameters","illustrated","considers","conditions","necessary","abstracts","introduced","calibration","experiment","corresponding","information","estimation","incomplete","detection","effective","annotation","reference","accessing","synthetic","optimizing","connected","optimization","confidential","decentralized","allocation","communication","performance","dirichlet","modelling","preserving","controlled","equivalent","undirected","conditional","independences","replacement","independence","relations","generating","ancestral","variables","different","represent","techniques","augmentation","riemannian","demonstrated","inference","difficulties","gradients","alternative","representation","marginalization","exploiting","constrained","challenging","approximation","probabilistic","representing","structure","independencies","probability","uncertainty","distribution","frequency","reporting","determining","graphical","probabilities","variances","application","distortion","quantization","specifically","correction","introduce","complexity","robustness","classification","classifiers","replication","strategies","traditional","polynomial","correcting","minimizing","corrupted","redundancy","multiplication","classifier","optimized","resolution","understanding","properties","validation","arbitrarily","significant","guarantee","challenge","distributions","predictive","previously","fundamental","illustrate","tradeoffs","observing","instances","formulated","supervise","appropriate","parametrizes","relaxation","computational","assignment","collection","quadratic","interested","structural","substitute","impossible","efficient","expensive","eventually","reliability","simulation","prescribed","substitution","functions","substituting","augmented","importance","surrogate","metamodel","expansions","engineering","analytical","reconstructed","unobserved","independently","navigation","approaches","environments","reconstruction","magnitude","framework","acquisition","technique","binocular","separation","conventional","mathematical","situations","sensitivity","monocular","environment","processing","scenarios","direction","applications","constructing","experiments","recognition","challenges","extensive","contribution","convolutional","intellectual","exploring","facilitate","comprehensive","protection","axiomatic","relationships","presented","perspective","evaluating","presenting","partition","attackers","semantics","interacting","valuations","assessment","defenders","respectively","respective","arguments","extensions","skeptical","argumentation","classical","eligibility","microsoft","government","coordinate","selection","placement","prospective","attribute","procedures","employment","guidelines","registration","determine","sequential","development","implementation","abstraction","unnecessary","enforcing","retrieval","descriptive","categories","evaluation","available","hierarchical","containing","extracted","compression","alternatives","representations","interactively","processes","meanwhile","validated","outperformed","dynamically","propagation","mechanism","automated","objectness","importantly","interact ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	independences
# 	ancestral
# 	exposition
# 	nontrivially
# 	integrations
# 	confounders
# 	eigendecomposition
# 	blackwellisation
# 	nonconvexity
# 	maximisation
# 	parkinsons
# 	jacobians
# 	projectorg
# 	fractions
# 	negativity
# 	dispersion
# 	supermarket
# 	datapoint
# 	unmeasured
# 	prognostics
# Some words which never appear in Statistics papers:
# 	pseudoinverse
# 	binocular
# 	monocular
# 	intellectual
# 	valuations
# 	skeptical
# 	argumentation
# 	eligibility
# 	government
# 	adherence
# 	authentic
# 	inheritance
# 	enumerates
# 	bibliographic
# 	connectionist
# 	fluctuating
# 	bifurcation
# 	resistance
# 	discourse
# 	unification

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.0933894267949395e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7791666666666667
